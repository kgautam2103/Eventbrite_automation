# %% [markdown]
# <a href="https://colab.research.google.com/github/kgautam2103/Eventbrite_automation/blob/main/create_single_event_eventbrite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# when you run this code, you will get a link below
#Follow the link, copy the code, paste it in the box and then press Enter on the keyboard.
#This will authenticate you and will allow you to interact with Google Sheets and other Google apps in your notebook.
from google.colab import auth
auth.authenticate_user()
import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
import pandas as pd
import requests
import json
import time
from datetime import datetime

#define global variables
auth_token = ''
prod_url = 'https://www.eventbriteapi.com/v3/'
prod_proxy_url= 'https://private-anon-558389a6a9-eventbriteapiv3public.apiary-proxy.com/v3/'
mock_url='https://private-anon-86d996fd56-eventbriteapiv3public.apiary-mock.com/v3/'
org = 'organizations/'
venues= '/venues/'
events= 'events/'
copy= '/copy/'
publish= '/publish/'
#start_date='2021-08-24T00:45:00Z'
#end_date='2021-08-24T01:45:00Z'
start_date = input('enter the start date as 2021-08-24T00:45:00Z : ')
end_date = input('enter the end date as 2021-08-24T00:45:00Z : ')
current_ts = datetime.now().strftime('%Y%m%d%H%M%S')
output_sheet = current_ts+'_event_output'
counter=1

authorization = 'Bearer '+auth_token
headers = {
        'Authorization': authorization,
        'Content-Type': 'application/json'
    }

wb = gc.open_by_url('https://docs.google.com/spreadsheets/d/1ryMfzfy6u2N0V4qg1B-xzRYTaNcs_e4o-DBddru1raI/edit#gid=0')

# create and Open our new sheet and add some data.
sh = gc.create(output_sheet)
output_sheet = gc.open(output_sheet).sheet1

output_sheet.insert_row(['event_url','event_id','is_published','venue_id','city','region','postal_code','country','org_id','venue_error','event_error'],1)

sheet_name = input('enter the name of input sheet : ')
input_sheet = wb.worksheet(sheet_name)
inputdata = input_sheet.get_all_values()
inputdata_df = pd.DataFrame(inputdata, columns=['name',	'capacity','address1','address2','city','region',
                                                'postal_code','country','timezone','org_id','sample_event_id','replace_city'])
inputdata_df = inputdata_df.drop(inputdata_df.index[0])

for index,row in inputdata_df.iterrows():
  counter = counter+1
  venue_id=""
  venue_error=""
  event_id = ""
  event_error = ""
  copy_error = ""
  update_error = ""
  publish_error = ""
  is_published = False
  cell_value_list = []
  address_details={
        "address_1": str(row['address1']),
        "address_2": str(row['address2']),
        "city": str(row['city']),
        "region": str(row['region']),
        "postal_code": str(row['postal_code']),
        "country": str(row['country'])
    }

  venue_details = {
        "name": str(row['name']),
        "capacity": str(row['capacity']),
        "address":address_details
        }

  final_venue_body = {
        "venue": venue_details
    }

  organization_id = str(row['org_id']).strip()
  venue_url = prod_url + org + organization_id + venues
  venue_values = json.dumps(final_venue_body)

  venue_response = requests.post(venue_url,data=venue_values,headers=headers)
  venue_status = venue_response.status_code

  if venue_status == 200:
    venue_id = str(venue_response.json()['id'])
  else:
    venue_error = venue_response.text

  print("venue_id "+venue_id)
  print("venue_status "+str(venue_status))
  print("venue_error "+venue_error)

  city_name = str(row['city'])
  sample_event_id = str(row['sample_event_id'])
  retrieve_event_url = prod_url+events+sample_event_id
  retrieve_response = requests.get(retrieve_event_url,headers=headers)

  event_name = str(retrieve_response.json()['name']['text'])
  event_desc = str(retrieve_response.json()['description']['text'])
  new_event_name = event_name.replace(str(row['replace_city']),city_name)
  new_event_desc = event_desc.replace(str(row['replace_city']),city_name)

  copy_event_url = prod_url+events+sample_event_id+copy
  copy_response = requests.post(copy_event_url,headers=headers)
  copy_status = copy_response.status_code

  if copy_status == 200:
    event_id = str(copy_response.json()['id'])
  else:
    copy_error = copy_response.text

  print("event_id "+event_id)
  print("copy_status "+str(copy_status))
  print("copy_error "+copy_error)

  update_event_url = prod_url+events+event_id+"/"
  publish_event_url = prod_url+events+event_id+publish
  timezone = str(row['timezone']).strip()

  print(new_event_name)

  update_request_body = {"event": {"name": {
        "html": new_event_name},"description": {
        "html": new_event_desc},"venue_id": venue_id,
          "start": {"timezone": timezone, "utc": start_date},
          "end": {"timezone": timezone, "utc": end_date}
      }
      }

  update_event_values = json.dumps(update_request_body)
  print(update_event_values)

  update_response = requests.post(update_event_url, data=update_event_values, headers=headers)
  update_status = update_response.status_code

  print(update_response.json())
  print("update_status "+str(update_status))

  if update_status == 200:
    #time.sleep(60)
    publish_response = requests.post(publish_event_url,headers=headers)
    publish_status = publish_response.status_code
    if publish_status == 200:
      is_published=True
    else:
      publish_error = publish_response.text
  else:
    update_error = update_response.text

  print(is_published)
  event_error = copy_error+update_error+publish_error
  print("event_error "+event_error)
  event_url = "https://www.eventbrite.com/myevent?eid="+event_id
  cell_value_list = [event_url,event_id,is_published,venue_id,city_name,str(row['region']),str(row['postal_code']),str(row['country']),organization_id,venue_error,event_error]
  output_sheet.insert_row(cell_value_list,counter)
# Out:
# venue_id 186204009
# venue_status 200
# venue_error
# event_id 768485329307
# copy_status 200
# copy_error
# Philadelphia: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Philadelphia: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Philadelphia: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204009", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Philadelphia: FREE 21-Day Online Meditation Course!', 'html': 'Philadelphia: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Philadelphia: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Philadelphia: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/philadelphia-free-21-day-online-meditation-course-tickets-768485329307', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:38:52Z', 'changed': '2023-11-28T18:38:55Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Philadelphia: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649705089', 'organizer_id': '56820245883', 'venue_id': '186204009', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768485329307', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768485329307/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705089%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=a4cb0c283bea38d7ad4ce27c93fb1e1c', 'width': 2160, 'height': 1080}, 'id': '649705089', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705089%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=7d4b81e0cd70a94502e0df9fea917765', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204049
# venue_status 200
# venue_error
# event_id 768486412547
# copy_status 200
# copy_error
# Detroit: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Detroit: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Detroit: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204049", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Detroit: FREE 21-Day Online Meditation Course!', 'html': 'Detroit: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Detroit: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Detroit: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/detroit-free-21-day-online-meditation-course-tickets-768486412547', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:39:02Z', 'changed': '2023-11-28T18:39:05Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Detroit: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649705249', 'organizer_id': '56820245883', 'venue_id': '186204049', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768486412547', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768486412547/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705249%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=5ba1f2dc8e5028e4b95c3eb05a2b935e', 'width': 2160, 'height': 1080}, 'id': '649705249', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705249%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=4c1a6042c1ee017b0c85a250ffbefd8a', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204139
# venue_status 200
# venue_error
# event_id 768486492787
# copy_status 200
# copy_error
# Jacksonville: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Jacksonville: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Jacksonville: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204139", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Jacksonville: FREE 21-Day Online Meditation Course!', 'html': 'Jacksonville: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Jacksonville: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Jacksonville: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/jacksonville-free-21-day-online-meditation-course-tickets-768486492787', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:39:14Z', 'changed': '2023-11-28T18:39:17Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Jacksonville: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649705469', 'organizer_id': '56820245883', 'venue_id': '186204139', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768486492787', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768486492787/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705469%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=208235d9f022b996e83df90000516d58', 'width': 2160, 'height': 1080}, 'id': '649705469', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705469%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=00b57ed1a8066ade3e339abea407a12a', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204199
# venue_status 200
# venue_error
# event_id 768486552967
# copy_status 200
# copy_error
# Columbus: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Columbus: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Columbus: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204199", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Columbus: FREE 21-Day Online Meditation Course!', 'html': 'Columbus: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Columbus: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Columbus: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/columbus-free-21-day-online-meditation-course-tickets-768486552967', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:39:26Z', 'changed': '2023-11-28T18:39:30Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Columbus: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649705629', 'organizer_id': '56820245883', 'venue_id': '186204199', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768486552967', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768486552967/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705629%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=360eb5356d1da8e0dc9793beea9d8d89', 'width': 2160, 'height': 1080}, 'id': '649705629', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705629%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=0d7fe69e52f5c00e2821368d07e6eff4', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204249
# venue_status 200
# venue_error
# event_id 768486623177
# copy_status 200
# copy_error
# Baltimore: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Baltimore: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Baltimore: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204249", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Baltimore: FREE 21-Day Online Meditation Course!', 'html': 'Baltimore: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Baltimore: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Baltimore: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/baltimore-free-21-day-online-meditation-course-tickets-768486623177', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:39:38Z', 'changed': '2023-11-28T18:39:41Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Baltimore: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649705779', 'organizer_id': '56820245883', 'venue_id': '186204249', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768486623177', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768486623177/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705779%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=b50ce0e5924a29236c0e1f665989f544', 'width': 2160, 'height': 1080}, 'id': '649705779', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705779%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=2a2acf92ba3369b1a6d6549f96fa8fdc', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204299
# venue_status 200
# venue_error
# event_id 768486683357
# copy_status 200
# copy_error
# Charlotte: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Charlotte: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Charlotte: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204299", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Charlotte: FREE 21-Day Online Meditation Course!', 'html': 'Charlotte: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Charlotte: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Charlotte: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/charlotte-free-21-day-online-meditation-course-tickets-768486683357', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:39:48Z', 'changed': '2023-11-28T18:39:51Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Charlotte: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649705899', 'organizer_id': '56820245883', 'venue_id': '186204299', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768486683357', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768486683357/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705899%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=6840f041b551c4edaaf4722868dbb4df', 'width': 2160, 'height': 1080}, 'id': '649705899', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649705899%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=08ab4fb8a83287381a84e9f29bcafe34', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204349
# venue_status 200
# venue_error
# event_id 768486713447
# copy_status 200
# copy_error
# Louisville: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Louisville: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Louisville: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204349", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Louisville: FREE 21-Day Online Meditation Course!', 'html': 'Louisville: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Louisville: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Louisville: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/louisville-free-21-day-online-meditation-course-tickets-768486713447', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:39:59Z', 'changed': '2023-11-28T18:40:02Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Louisville: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649706029', 'organizer_id': '56820245883', 'venue_id': '186204349', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768486713447', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768486713447/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706029%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=470ac516229bb730f24dd94086e3b809', 'width': 2160, 'height': 1080}, 'id': '649706029', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706029%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=03cd8972448bba213cf360cade5445d5', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204389
# venue_status 200
# venue_error
# event_id 768486753567
# copy_status 200
# copy_error
# Washington: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Washington: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Washington: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204389", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Washington: FREE 21-Day Online Meditation Course!', 'html': 'Washington: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Washington: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Washington: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/washington-free-21-day-online-meditation-course-tickets-768486753567', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:40:10Z', 'changed': '2023-11-28T18:40:13Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Washington: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649706119', 'organizer_id': '56820245883', 'venue_id': '186204389', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768486753567', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768486753567/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706119%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=51641d610c328945cb21d86a63594e2d', 'width': 2160, 'height': 1080}, 'id': '649706119', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706119%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=b03cb17d81340d66a3720653add7ffb2', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204449
# venue_status 200
# venue_error
# event_id 768486813747
# copy_status 200
# copy_error
# Atlanta: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Atlanta: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Atlanta: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204449", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Atlanta: FREE 21-Day Online Meditation Course!', 'html': 'Atlanta: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Atlanta: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Atlanta: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/atlanta-free-21-day-online-meditation-course-tickets-768486813747', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:40:19Z', 'changed': '2023-11-28T18:40:22Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Atlanta: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649706259', 'organizer_id': '56820245883', 'venue_id': '186204449', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768486813747', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768486813747/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706259%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=a493cde00424199342415c21573d70b6', 'width': 2160, 'height': 1080}, 'id': '649706259', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706259%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=af95aa894d6268478a7ea14f14c353a2', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204479
# venue_status 200
# venue_error
# event_id 768486853867
# copy_status 200
# copy_error
# Cleveland: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Cleveland: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Cleveland: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204479", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Cleveland: FREE 21-Day Online Meditation Course!', 'html': 'Cleveland: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Cleveland: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Cleveland: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/cleveland-free-21-day-online-meditation-course-tickets-768486853867', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:40:29Z', 'changed': '2023-11-28T18:40:32Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Cleveland: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649706389', 'organizer_id': '56820245883', 'venue_id': '186204479', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768486853867', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768486853867/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706389%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=7c5eabd3ed1c733d1b0261dc411c13aa', 'width': 2160, 'height': 1080}, 'id': '649706389', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706389%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=1fc6a1de256fbcc3d9826adf4c2a3426', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204529
# venue_status 200
# venue_error
# event_id 768486964197
# copy_status 200
# copy_error
# Miami: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Miami: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Miami: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204529", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Miami: FREE 21-Day Online Meditation Course!', 'html': 'Miami: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Miami: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Miami: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/miami-free-21-day-online-meditation-course-tickets-768486964197', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:40:38Z', 'changed': '2023-11-28T18:40:41Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Miami: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649706459', 'organizer_id': '56820245883', 'venue_id': '186204529', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768486964197', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768486964197/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706459%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=2bfb5062b277e91276cd5b8352167a10', 'width': 2160, 'height': 1080}, 'id': '649706459', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706459%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=3b251c550bc605ccbad0187841ab0ccd', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204559
# venue_status 200
# venue_error
# event_id 768487034407
# copy_status 200
# copy_error
# Raleigh: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Raleigh: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Raleigh: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204559", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Raleigh: FREE 21-Day Online Meditation Course!', 'html': 'Raleigh: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Raleigh: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Raleigh: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/raleigh-free-21-day-online-meditation-course-tickets-768487034407', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:40:47Z', 'changed': '2023-11-28T18:40:50Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Raleigh: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649706649', 'organizer_id': '56820245883', 'venue_id': '186204559', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768487034407', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768487034407/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706649%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=9bf87f75d1a09787ba743850d26be3ed', 'width': 2160, 'height': 1080}, 'id': '649706649', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706649%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=58134fe813c0fd7c7125ce73fa66a092', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204629
# venue_status 200
# venue_error
# event_id 768487114647
# copy_status 200
# copy_error
# Tampa: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Tampa: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Tampa: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204629", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Tampa: FREE 21-Day Online Meditation Course!', 'html': 'Tampa: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Tampa: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Tampa: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/tampa-free-21-day-online-meditation-course-tickets-768487114647', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:40:56Z', 'changed': '2023-11-28T18:40:59Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Tampa: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649706709', 'organizer_id': '56820245883', 'venue_id': '186204629', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768487114647', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768487114647/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706709%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=d08ab41491ccbdf3378bd9621b3f75c5', 'width': 2160, 'height': 1080}, 'id': '649706709', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706709%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=46f6fecd82e694316146e691e6bede62', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204659
# venue_status 200
# venue_error
# event_id 768487144737
# copy_status 200
# copy_error
# Cincinnati: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Cincinnati: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Cincinnati: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204659", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Cincinnati: FREE 21-Day Online Meditation Course!', 'html': 'Cincinnati: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Cincinnati: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Cincinnati: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/cincinnati-free-21-day-online-meditation-course-tickets-768487144737', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:41:05Z', 'changed': '2023-11-28T18:41:08Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Cincinnati: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649706829', 'organizer_id': '56820245883', 'venue_id': '186204659', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768487144737', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768487144737/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706829%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=055f83c89fc00cb8698f11010b21d3b4', 'width': 2160, 'height': 1080}, 'id': '649706829', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649706829%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=d4d59c6c81ef4064c24aedc0cc8e3bba', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204759
# venue_status 200
# venue_error
# event_id 768487245037
# copy_status 200
# copy_error
# Lexington: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Lexington: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Lexington: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204759", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Lexington: FREE 21-Day Online Meditation Course!', 'html': 'Lexington: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Lexington: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Lexington: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/lexington-free-21-day-online-meditation-course-tickets-768487245037', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:41:16Z', 'changed': '2023-11-28T18:41:19Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Lexington: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649707049', 'organizer_id': '56820245883', 'venue_id': '186204759', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768487245037', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768487245037/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649707049%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=19299ae5f4ef907be043d12af838911b', 'width': 2160, 'height': 1080}, 'id': '649707049', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649707049%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=b9e16fb0efcc5f3d23cab4b9468317ab', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204829
# venue_status 200
# venue_error
# event_id 768487345337
# copy_status 200
# copy_error
# Orlando: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Orlando: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Orlando: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186204829", "start": {"timezone": "America/New_York", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/New_York", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Orlando: FREE 21-Day Online Meditation Course!', 'html': 'Orlando: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Orlando: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Orlando: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/orlando-free-21-day-online-meditation-course-tickets-768487345337', 'start': {'timezone': 'America/New_York', 'local': '2024-01-27T20:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/New_York', 'local': '2024-02-16T21:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T18:41:27Z', 'changed': '2023-11-28T18:41:31Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Orlando: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649707309', 'organizer_id': '56820245883', 'venue_id': '186204829', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768487345337', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768487345337/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649707309%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=f7e6a2fd7d22c88485ca1b51d1eb9306', 'width': 2160, 'height': 1080}, 'id': '649707309', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649707309%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=ded250bc3d80f2bfbda124de7210758d', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186204889
# venue_status 200
# venue_error
# event_id 768488418547
# copy_status 200
# copy_error
# Yonkers: FREE 21-Day Online Meditation Course!
# ...
# update_status 200
# True
# event_error
# venue_id 186213249
# venue_status 200
# venue_error
# event_id 768523042107
# copy_status 200
# copy_error
# Santa Maria: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Santa Maria: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Santa Maria: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186213249", "start": {"timezone": "America/Los_Angeles", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/Los_Angeles", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Santa Maria: FREE 21-Day Online Meditation Course!', 'html': 'Santa Maria: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Santa Maria: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Santa Maria: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/santa-maria-free-21-day-online-meditation-course-tickets-768523042107', 'start': {'timezone': 'America/Los_Angeles', 'local': '2024-01-27T17:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/Los_Angeles', 'local': '2024-02-16T18:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T19:08:06Z', 'changed': '2023-11-28T19:08:09Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Santa Maria: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649731659', 'organizer_id': '56820245883', 'venue_id': '186213249', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768523042107', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768523042107/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649731659%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=4834b563fb159d7dc7ef7b5d09d17ec4', 'width': 2160, 'height': 1080}, 'id': '649731659', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649731659%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=36842bbca131d606f388c1c46a71d38e', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186213279
# venue_status 200
# venue_error
# event_id 768525108287
# copy_status 200
# copy_error
# Chico: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Chico: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Chico: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186213279", "start": {"timezone": "America/Los_Angeles", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/Los_Angeles", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Chico: FREE 21-Day Online Meditation Course!', 'html': 'Chico: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Chico: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Chico: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/chico-free-21-day-online-meditation-course-tickets-768525108287', 'start': {'timezone': 'America/Los_Angeles', 'local': '2024-01-27T17:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/Los_Angeles', 'local': '2024-02-16T18:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T19:08:16Z', 'changed': '2023-11-28T19:08:20Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Chico: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649731809', 'organizer_id': '56820245883', 'venue_id': '186213279', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768525108287', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768525108287/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649731809%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=f4db08fa4bf90e1d243d7628cf3370ac', 'width': 2160, 'height': 1080}, 'id': '649731809', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649731809%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=9fc2a154265bd510618bf6e82f688ebd', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186213329
# venue_status 200
# venue_error
# event_id 768525158437
# copy_status 200
# copy_error
# Eureka: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Eureka: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Eureka: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186213329", "start": {"timezone": "America/Los_Angeles", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/Los_Angeles", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Eureka: FREE 21-Day Online Meditation Course!', 'html': 'Eureka: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Eureka: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Eureka: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/eureka-free-21-day-online-meditation-course-tickets-768525158437', 'start': {'timezone': 'America/Los_Angeles', 'local': '2024-01-27T17:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/Los_Angeles', 'local': '2024-02-16T18:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T19:08:26Z', 'changed': '2023-11-28T19:08:29Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Eureka: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649732019', 'organizer_id': '56820245883', 'venue_id': '186213329', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768525158437', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768525158437/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649732019%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=860254965aedddcc52dc167d64f4a9fe', 'width': 2160, 'height': 1080}, 'id': '649732019', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649732019%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=09b5416a9a9c09bba721d97219e51a51', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186213369
# venue_status 200
# venue_error
# event_id 768525218617
# copy_status 200
# copy_error
# Mammoth Lakes: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Mammoth Lakes: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Mammoth Lakes: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186213369", "start": {"timezone": "America/Los_Angeles", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/Los_Angeles", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Mammoth Lakes: FREE 21-Day Online Meditation Course!', 'html': 'Mammoth Lakes: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Mammoth Lakes: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Mammoth Lakes: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/mammoth-lakes-free-21-day-online-meditation-course-tickets-768525218617', 'start': {'timezone': 'America/Los_Angeles', 'local': '2024-01-27T17:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/Los_Angeles', 'local': '2024-02-16T18:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T19:08:36Z', 'changed': '2023-11-28T19:08:39Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Mammoth Lakes: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649732119', 'organizer_id': '56820245883', 'venue_id': '186213369', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768525218617', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768525218617/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649732119%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=379f065b9a1720c79376195710ceaee7', 'width': 2160, 'height': 1080}, 'id': '649732119', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649732119%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=07a68982418eca643fef84eccc598ae8', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 186213429
# venue_status 200
# venue_error
# event_id 768525268767
# copy_status 200
# copy_error
# Las Vegas: FREE 21-Day Online Meditation Course!
# {"event": {"name": {"html": "Las Vegas: FREE 21-Day Online Meditation Course!"}, "description": {"html": "Las Vegas: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 \u2013 FRIDAY, FEB 16, 2023"}, "venue_id": "186213429", "start": {"timezone": "America/Los_Angeles", "utc": "2024-01-28T01:45:00Z"}, "end": {"timezone": "America/Los_Angeles", "utc": "2024-02-17T02:45:00Z"}}}
# {'name': {'text': 'Las Vegas: FREE 21-Day Online Meditation Course!', 'html': 'Las Vegas: FREE 21-Day Online Meditation Course!'}, 'description': {'text': 'Las Vegas: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'html': 'Las Vegas: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023'}, 'url': 'https://www.eventbrite.com/e/las-vegas-free-21-day-online-meditation-course-tickets-768525268767', 'start': {'timezone': 'America/Los_Angeles', 'local': '2024-01-27T17:45:00', 'utc': '2024-01-28T01:45:00Z'}, 'end': {'timezone': 'America/Los_Angeles', 'local': '2024-02-16T18:45:00', 'utc': '2024-02-17T02:45:00Z'}, 'organization_id': '1227441422413', 'created': '2023-11-28T19:08:45Z', 'changed': '2023-11-28T19:08:48Z', 'capacity': 300, 'capacity_is_custom': True, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': False, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Las Vegas: FREE 21-Day Online Meditation Course!, SATURDAY, JAN 27 – FRIDAY, FEB 16, 2023', 'facebook_event_id': None, 'logo_id': '649732219', 'organizer_id': '56820245883', 'venue_id': '186213429', 'category_id': '107', 'subcategory_id': '7005', 'format_id': '9', 'id': '768525268767', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/768525268767/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0}, 'width': 2160, 'height': 1080}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649732219%2F1227439176803%2F1%2Foriginal.20231122-194055?auto=format%2Ccompress&q=75&sharp=10&s=d8f80edd806f348782c6b38d9aa10932', 'width': 2160, 'height': 1080}, 'id': '649732219', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F649732219%2F1227439176803%2F1%2Foriginal.20231122-194055?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C0%2C2160%2C1080&s=cae2d96ac173904f03f785fa4d897bf4', 'aspect_ratio': '2', 'edge_color': '#66a2d3', 'edge_color_set': True}}
# update_status 200
# True
# event_error
