# %% [markdown]
# <a href="https://colab.research.google.com/github/kgautam2103/Eventbrite_automation/blob/main/delete_events_eventbrite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This will authenticate you and will allow you to interact with Google Sheets and other Google apps in your notebook.
from google.colab import auth
auth.authenticate_user()
import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
import pandas as pd
import requests
import json
from datetime import datetime

#define global variables
auth_token = ''
prod_url = 'https://www.eventbriteapi.com/v3/'
prod_proxy_url= 'https://private-anon-a95bf0df64-eventbriteapiv3public.apiary-proxy.com/v3/'
mock_url='https://private-anon-86d996fd56-eventbriteapiv3public.apiary-mock.com/v3/'
org = 'organizations/'
venues= '/venues/'
events= 'events/'
copy= '/copy/'
publish= '/publish/'
current_ts = datetime.now().strftime('%Y%m%d%H%M%S')
output_sheet = current_ts+'_delete_output'
counter=1


authorization = 'Bearer ' + auth_token
auth_headers = {
    'Authorization': authorization,
    'Content-Type': 'application/json'
    }

wb = gc.open_by_url('https://docs.google.com/spreadsheets/d/1qqkU8TFyJxbu8ccem3cGWr61JRqk3m46NNYuPEakt2o/edit#gid=0')

# create and Open our new sheet and add some data.
sh = gc.create(output_sheet)
output_sheet = gc.open(output_sheet).sheet1

output_sheet.insert_row(['event_id',	'is_deleted', 'error'],1)

input_sheet = input("enter the input sheet name: ")
input = wb.worksheet(str(input_sheet))
inputdata = input.get_all_values()
inputdata_df = pd.DataFrame(inputdata, columns=['event_id'])
inputdata_df = inputdata_df.drop(inputdata_df.index[0])

for index, row in inputdata_df.iterrows():
  counter = counter+1
  is_deleted = False
  delete_error = ""
  cell_value_list = []
  event_id = str(row['event_id']).strip()
  delete_event_url = prod_url+events+event_id
  delete_response = requests.delete(delete_event_url,headers=auth_headers)
  delete_status = delete_response.status_code
  print("event_id "+event_id)
  print(delete_response.text)
  if delete_status == 200:
    is_deleted = True
  else:
    delete_error = delete_response.text

  cell_value_list = [event_id,is_deleted,delete_error]
  output_sheet.insert_row(cell_value_list,counter)
# Out:
# enter the input sheet name: inputdata
# event_id 670496843107
# {"status_code":400,"error_description":"This event cannot be deleted.","error":"CANNOT_DELETE"}
# event_id 670496863167
# {"deleted":true}
# event_id 670496893257
# {"deleted":true}
# event_id 670496903287
# {"deleted":true}
# event_id 670496933377
# {"deleted":true}
# event_id 670497003587
# {"deleted":true}
# event_id 670497023647
# {"deleted":true}
# event_id 670497033677
# {"deleted":true}
# event_id 670497083827
# {"deleted":true}
# event_id 670497123947
# {"deleted":true}
# event_id 670497144007
# {"status_code":400,"error_description":"This event cannot be deleted.","error":"CANNOT_DELETE"}
# event_id 670497164067
# {"deleted":true}
# event_id 670497204187
# {"deleted":true}
# event_id 670497244307
# {"deleted":true}
# event_id 670497264367
# {"deleted":true}
# event_id 670497294457
# {"deleted":true}
# event_id 670497304487
# {"deleted":true}
# event_id 670497344607
# {"deleted":true}
# event_id 670497364667
# {"deleted":true}
# event_id 670497394757
# {"deleted":true}
# event_id 670497404787
# {"deleted":true}
# event_id 670497444907
# {"deleted":true}
# event_id 670497464967
# {"deleted":true}
# event_id 670497495057
# {"deleted":true}
# event_id 670497515117
# {"deleted":true}
# event_id 670497555237
# {"deleted":true}
# event_id 670497575297
# {"deleted":true}
# event_id 670497605387
# {"deleted":true}
# event_id 670497625447
# {"deleted":true}
# event_id 670497645507
# {"deleted":true}
# event_id 670497695657
# {"deleted":true}
# event_id 670497705687
# {"deleted":true}
# event_id 670497725747
# {"deleted":true}
# event_id 670497755837
# {"deleted":true}
# event_id 670497765867
# {"deleted":true}
# event_id 670498457937
# {"deleted":true}
# event_id 670498488027
# {"deleted":true}
# event_id 670498528147
# {"deleted":true}
# event_id 670498548207
# {"deleted":true}
# event_id 670498568267
# {"deleted":true}
# event_id 670498588327
# {"deleted":true}
# event_id 670498608387
# {"deleted":true}
# event_id 670498638477
# {"deleted":true}
# event_id 670498648507
# {"deleted":true}
# event_id 670499109887
# {"deleted":true}
# event_id 670499139977
# {"deleted":true}
# event_id 670499160037
# {"deleted":true}
# event_id 670499180097
# {"deleted":true}
# event_id 670499210187
# {"deleted":true}
# event_id 670499230247
# {"deleted":true}
# event_id 670499260337
# {"deleted":true}
# event_id 670499290427
# {"deleted":true}
# event_id 670499300457
# {"deleted":true}
# event_id 670500122917
# {"deleted":true}
# event_id 670500153007
# {"deleted":true}
# event_id 670500173067
# {"deleted":true}
# event_id 670500203157
# {"deleted":true}
# event_id 670500283397
# {"deleted":true}
# event_id 670500303457
# {"deleted":true}
# event_id 670500333547
# {"deleted":true}
# event_id 670500865137
# {"deleted":true}
# event_id 670500985497
# {"deleted":true}
# event_id 670501005557
# {"deleted":true}
# event_id 670501025617
# {"deleted":true}
# event_id 670501055707
# {"deleted":true}
# event_id 670501075767
# {"deleted":true}
# event_id 670501085797
# {"deleted":true}
# event_id 670501105857
# {"deleted":true}
# event_id 670501125917
# {"deleted":true}
# event_id 670501156007
# {"deleted":true}
# event_id 670501176067
# {"deleted":true}
# event_id 670501226217
# {"deleted":true}
# event_id 670501266337
# {"deleted":true}
# event_id 670501296427
# {"deleted":true}
# event_id 670501306457
# {"deleted":true}
# event_id 670501326517
# {"deleted":true}
# event_id 670501346577
# {"deleted":true}
# event_id 670501497027
# {"deleted":true}
# event_id 670501517087
# {"deleted":true}
# event_id 670501537147
# {"deleted":true}
# event_id 670501557207
# {"deleted":true}
# event_id 670501577267
# {"deleted":true}
# event_id 670501607357
# {"deleted":true}
# event_id 670501647477
# {"deleted":true}
# event_id 670501667537
# {"deleted":true}
# event_id 670501697627
# {"deleted":true}
# event_id 670501747777
# {"deleted":true}
# event_id 670501757807
# {"deleted":true}
# event_id 670501807957
# {"deleted":true}
# event_id 670501888197
# {"deleted":true}
# event_id 670501928317
# {"deleted":true}
# event_id 670501958407
# {"deleted":true}
# event_id 670501988497
# {"deleted":true}
# event_id 670501998527
# {"deleted":true}
# event_id 670502028617
# {"deleted":true}
# event_id 670502068737
# {"deleted":true}
# event_id 670502098827
# {"deleted":true}
# event_id 670502118887
# {"deleted":true}
# event_id 670502138947
# {"deleted":true}
# event_id 670502159007
# {"deleted":true}
# event_id 670502169037
# {"deleted":true}
# event_id 670502189097
# {"deleted":true}
# event_id 670502229217
# {"deleted":true}
# event_id 670502239247
# {"deleted":true}
# event_id 670502269337
# {"deleted":true}
# event_id 670502289397
# {"deleted":true}
# event_id 670502319487
# {"deleted":true}
# event_id 670502359607
# {"deleted":true}
# event_id 670502389697
# {"deleted":true}
# event_id 670502419787
# {"deleted":true}
# event_id 670502439847
# {"deleted":true}
# event_id 670502459907
# {"deleted":true}
# event_id 670502479967
# {"deleted":true}
# event_id 670502500027
# {"deleted":true}
# event_id 670502530117
# {"deleted":true}
# event_id 670502560207
# {"deleted":true}
# event_id 670502580267
# {"deleted":true}
# event_id 670502600327
# {"deleted":true}
# event_id 670502630417
# {"deleted":true}
# event_id 670502670537
# {"deleted":true}
# event_id 670502700627
# {"deleted":true}
# event_id 670502770837
# {"deleted":true}
# event_id 670502790897
# {"deleted":true}
# event_id 670502820987
# {"deleted":true}
# event_id 670502881167
# {"deleted":true}
# event_id 670502901227
# {"deleted":true}
# event_id 670502931317
# {"deleted":true}
# event_id 670502951377
# {"deleted":true}
# event_id 670503091797
# {"deleted":true}
# event_id 670503101827
# {"deleted":true}
# event_id 670503232217
# {"deleted":true}
# event_id 670503272337
# {"deleted":true}
# event_id 670503974437
# {"deleted":true}
# event_id 670504004527
# {"deleted":true}
# event_id 670504044647
# {"deleted":true}
# event_id 670504084767
# {"deleted":true}
# event_id 670504124887
# {"deleted":true}
# event_id 670504165007
# {"deleted":true}
# event_id 670504185067
# {"deleted":true}
# event_id 670504385667
# {"deleted":true}
# event_id 670504445847
# {"deleted":true}
# event_id 670504485967
# {"deleted":true}
# event_id 670504506027
# {"deleted":true}
# event_id 670504556177
# {"deleted":true}
# event_id 670504596297
# {"deleted":true}
# event_id 670504636417
# {"deleted":true}
# event_id 670504666507
# {"deleted":true}
# event_id 670504696597
# {"deleted":true}
# event_id 670504726687
# {"deleted":true}
# event_id 670504756777
# {"deleted":true}
# event_id 670504786867
# {"deleted":true}
# event_id 670504957377
# {"deleted":true}
# event_id 670505017557
# {"deleted":true}
# event_id 670505077737
# {"deleted":true}
# event_id 670505559177
# {"deleted":true}
# event_id 670505609327
# {"deleted":true}
# event_id 670505639417
# {"deleted":true}
